# %%
from matplotlib import pyplot as plt
import numpy as np 
import pandas as pd 

# Data Loading
data = pd.read_csv("E:\Cancer cell prediction\Skin-Cancer-Prediction\DATASET\hmnist_28_28_RGB.csv")
data.head()
meta_df = pd.read_csv("E:\Cancer cell prediction\Skin-Cancer-Prediction\DATASET\HAM10000_metadata.csv")
meta_df.head()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:8: SyntaxWarning: invalid escape sequence '\C'
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:8: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_11072\1069214988.py:6: SyntaxWarning: invalid escape sequence '\C'
#   data = pd.read_csv("E:\Cancer cell prediction\Skin-Cancer-Prediction\DATASET\hmnist_28_28_RGB.csv")
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_11072\1069214988.py:8: SyntaxWarning: invalid escape sequence '\C'
#   meta_df = pd.read_csv("E:\Cancer cell prediction\Skin-Cancer-Prediction\DATASET\HAM10000_metadata.csv")
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
import tensorflow as tf

# Check for available GPUs
physical_devices = tf.config.list_physical_devices('GPU')

# If GPUs are available, configure session to use them
if len(physical_devices) > 0:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
  logical_devices = tf.config.list_logical_devices('GPU')

  print(logical_devices)

# %%
meta_df.shape
data.shape
# Out:
# (10015, 2353)

# %%
yData = data['label']
XData = data.drop(columns = ['label'])
# EDA
distribution = meta_df['dx'].value_counts()
distribution
# classes = {4: ('nv', ' melanocytic nevi'),
#            6: ('mel', 'melanoma'),
#            2 :('bkl', 'benign keratosis-like lesions'), 
#            1:('bcc' , ' basal cell carcinoma'),
#            5: ('vasc', ' pyogenic granulomas and hemorrhage'),
#            0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
#            3: ('df', 'dermatofibroma')}
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
dist = data['label'].value_counts()
dist
distribution.plot()
plt.title('Distribution of Skin Cancer Classes')
plt.show()

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\sneha\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (2.1.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\sneha\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\sneha\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn->imblearn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\sneha\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\sneha\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.13.0 imblearn-0.0 sklearn-compat-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Fixing Data Imbalance

from imblearn.over_sampling import RandomOverSampler 
sampler = RandomOverSampler()
XData,yData  = sampler.fit_resample(XData,yData)
XData.shape, yData.shape
XData = np.array(XData).reshape((-1, 28, 28, 3))
XData = XData / 255
XData.shape
# Out:
# (46935, 28, 28, 3)

# %%
# Create the train and validation set
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(XData,yData, test_size=0.2)
Xtrain.shape, Xtest.shape
# Out:
# ((37548, 28, 28, 3), (9387, 28, 28, 3))

# %%
# Train the model
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
import tensorflow as tf

img_width, img_height = 28,28

input_shape = (img_width, img_height, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (2, 2)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('swish'))
model.add(Dropout(0.5))
model.add(Dense(7))
model.add(Activation('softmax'))
# Out:
# C:\Users\Sneha\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='sparse_categorical_crossentropy',
optimizer='nadam',
metrics=['accuracy'])

# %%
callback = tf.keras.callbacks.ModelCheckpoint(filepath='skin.h5',
                                                  monitor='val_acc', mode='max',
                                                 verbose=1)

early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
history = model.fit(Xtrain,
                    Ytrain,
                    epochs = 100,
                    validation_data = (Xtest, Ytest),
                    callbacks=[callback, early_stopping])
# Out:
# Epoch 1/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 1.4090 - accuracy: 0.4415
# Epoch 1: saving model to skin.h5
# 1174/1174 [==============================] - 16s 13ms/step - loss: 1.4084 - accuracy: 0.4418 - val_loss: 1.0992 - val_accuracy: 0.5825
# Epoch 2/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 1.0530 - accuracy: 0.5966
# Epoch 2: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 1.0529 - accuracy: 0.5966 - val_loss: 0.8939 - val_accuracy: 0.6448
# Epoch 3/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.8863 - accuracy: 0.6653
# Epoch 3: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.8865 - accuracy: 0.6652 - val_loss: 0.7435 - val_accuracy: 0.7131
# Epoch 4/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.7678 - accuracy: 0.7110
# Epoch 4: saving model to skin.h5
# 1174/1174 [==============================] - 15s 13ms/step - loss: 0.7678 - accuracy: 0.7110 - val_loss: 0.6319 - val_accuracy: 0.7648
# Epoch 5/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.6892 - accuracy: 0.7405
# Epoch 5: saving model to skin.h5
# 1174/1174 [==============================] - 23s 19ms/step - loss: 0.6892 - accuracy: 0.7404 - val_loss: 0.5792 - val_accuracy: 0.7770
# Epoch 6/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.6218 - accuracy: 0.7658
# Epoch 6: saving model to skin.h5
# 1174/1174 [==============================] - 21s 18ms/step - loss: 0.6221 - accuracy: 0.7657 - val_loss: 0.5172 - val_accuracy: 0.7994
# Epoch 7/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.5710 - accuracy: 0.7835
# Epoch 7: saving model to skin.h5
# 1174/1174 [==============================] - 20s 17ms/step - loss: 0.5707 - accuracy: 0.7837 - val_loss: 0.4665 - val_accuracy: 0.8206
# Epoch 8/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.5245 - accuracy: 0.8029
# Epoch 8: saving model to skin.h5
# 1174/1174 [==============================] - 21s 18ms/step - loss: 0.5245 - accuracy: 0.8029 - val_loss: 0.4357 - val_accuracy: 0.8334
# Epoch 9/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.4815 - accuracy: 0.8165
# Epoch 9: saving model to skin.h5
# 1174/1174 [==============================] - 19s 16ms/step - loss: 0.4815 - accuracy: 0.8165 - val_loss: 0.4129 - val_accuracy: 0.8478
# Epoch 10/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.4474 - accuracy: 0.8338
# Epoch 10: saving model to skin.h5
# 1174/1174 [==============================] - 20s 17ms/step - loss: 0.4472 - accuracy: 0.8338 - val_loss: 0.3435 - val_accuracy: 0.8711
# Epoch 11/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.4076 - accuracy: 0.8469
# Epoch 11: saving model to skin.h5
# 1174/1174 [==============================] - 21s 18ms/step - loss: 0.4074 - accuracy: 0.8469 - val_loss: 0.3254 - val_accuracy: 0.8763
# Epoch 12/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.3850 - accuracy: 0.8520
# Epoch 12: saving model to skin.h5
# 1174/1174 [==============================] - 23s 20ms/step - loss: 0.3850 - accuracy: 0.8520 - val_loss: 0.3009 - val_accuracy: 0.8874
# Epoch 13/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.3537 - accuracy: 0.8670
# Epoch 13: saving model to skin.h5
# 1174/1174 [==============================] - 14s 12ms/step - loss: 0.3538 - accuracy: 0.8670 - val_loss: 0.2832 - val_accuracy: 0.8940
# Epoch 14/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.3392 - accuracy: 0.8701
# Epoch 14: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.3390 - accuracy: 0.8701 - val_loss: 0.2661 - val_accuracy: 0.8950
# Epoch 15/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.3243 - accuracy: 0.8760
# Epoch 15: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.3245 - accuracy: 0.8761 - val_loss: 0.2515 - val_accuracy: 0.9047
# Epoch 16/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.8843
# Epoch 16: saving model to skin.h5
# 1174/1174 [==============================] - 16s 13ms/step - loss: 0.3043 - accuracy: 0.8843 - val_loss: 0.2294 - val_accuracy: 0.9137
# Epoch 17/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.2859 - accuracy: 0.8918
# Epoch 17: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.2859 - accuracy: 0.8918 - val_loss: 0.2489 - val_accuracy: 0.9044
# Epoch 18/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.2804 - accuracy: 0.8934
# Epoch 18: saving model to skin.h5
# 1174/1174 [==============================] - 15s 13ms/step - loss: 0.2801 - accuracy: 0.8935 - val_loss: 0.2111 - val_accuracy: 0.9248
# Epoch 19/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.2663 - accuracy: 0.8986
# Epoch 19: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.2663 - accuracy: 0.8986 - val_loss: 0.2183 - val_accuracy: 0.9210
# Epoch 20/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.9044
# Epoch 20: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.2512 - accuracy: 0.9044 - val_loss: 0.1940 - val_accuracy: 0.9293
# Epoch 21/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9088
# Epoch 21: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.2452 - accuracy: 0.9088 - val_loss: 0.2065 - val_accuracy: 0.9208
# Epoch 22/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.2380 - accuracy: 0.9098
# Epoch 22: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.2380 - accuracy: 0.9099 - val_loss: 0.2077 - val_accuracy: 0.9252
# Epoch 23/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.2264 - accuracy: 0.9164
# Epoch 23: saving model to skin.h5
# 1174/1174 [==============================] - 20s 17ms/step - loss: 0.2263 - accuracy: 0.9165 - val_loss: 0.1833 - val_accuracy: 0.9380
# Epoch 24/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.2207 - accuracy: 0.9161
# Epoch 24: saving model to skin.h5
# 1174/1174 [==============================] - 22s 18ms/step - loss: 0.2207 - accuracy: 0.9161 - val_loss: 0.1728 - val_accuracy: 0.9394
# Epoch 25/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.2084 - accuracy: 0.9210
# Epoch 25: saving model to skin.h5
# 1174/1174 [==============================] - 21s 18ms/step - loss: 0.2084 - accuracy: 0.9210 - val_loss: 0.1665 - val_accuracy: 0.9427
# Epoch 26/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.2020 - accuracy: 0.9256
# Epoch 26: saving model to skin.h5
# 1174/1174 [==============================] - 21s 18ms/step - loss: 0.2020 - accuracy: 0.9256 - val_loss: 0.1532 - val_accuracy: 0.9444
# Epoch 27/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9270
# Epoch 27: saving model to skin.h5
# 1174/1174 [==============================] - 21s 17ms/step - loss: 0.1965 - accuracy: 0.9270 - val_loss: 0.1502 - val_accuracy: 0.9520
# Epoch 28/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.1914 - accuracy: 0.9290
# Epoch 28: saving model to skin.h5
# 1174/1174 [==============================] - 19s 16ms/step - loss: 0.1914 - accuracy: 0.9289 - val_loss: 0.1387 - val_accuracy: 0.9525
# Epoch 29/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1832 - accuracy: 0.9311
# Epoch 29: saving model to skin.h5
# 1174/1174 [==============================] - 15s 12ms/step - loss: 0.1831 - accuracy: 0.9312 - val_loss: 0.1431 - val_accuracy: 0.9524
# Epoch 30/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.1795 - accuracy: 0.9344
# Epoch 30: saving model to skin.h5
# 1174/1174 [==============================] - 15s 12ms/step - loss: 0.1794 - accuracy: 0.9344 - val_loss: 0.1438 - val_accuracy: 0.9476
# Epoch 31/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1761 - accuracy: 0.9337
# Epoch 31: saving model to skin.h5
# 1174/1174 [==============================] - 14s 12ms/step - loss: 0.1762 - accuracy: 0.9337 - val_loss: 0.1380 - val_accuracy: 0.9522
# Epoch 32/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1729 - accuracy: 0.9366
# Epoch 32: saving model to skin.h5
# 1174/1174 [==============================] - 15s 13ms/step - loss: 0.1730 - accuracy: 0.9365 - val_loss: 0.1399 - val_accuracy: 0.9530
# Epoch 33/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.1668 - accuracy: 0.9382
# Epoch 33: saving model to skin.h5
# 1174/1174 [==============================] - 15s 13ms/step - loss: 0.1667 - accuracy: 0.9383 - val_loss: 0.1410 - val_accuracy: 0.9520
# Epoch 34/100
# 1169/1174 [============================>.] - ETA: 0s - loss: 0.1606 - accuracy: 0.9413
# Epoch 34: saving model to skin.h5
# 1174/1174 [==============================] - 16s 13ms/step - loss: 0.1606 - accuracy: 0.9413 - val_loss: 0.1268 - val_accuracy: 0.9566
# Epoch 35/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1598 - accuracy: 0.9405
# Epoch 35: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1598 - accuracy: 0.9405 - val_loss: 0.1202 - val_accuracy: 0.9613
# Epoch 36/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.1513 - accuracy: 0.9440
# Epoch 36: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1512 - accuracy: 0.9440 - val_loss: 0.1272 - val_accuracy: 0.9587
# Epoch 37/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1557 - accuracy: 0.9424
# Epoch 37: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.1557 - accuracy: 0.9424 - val_loss: 0.1292 - val_accuracy: 0.9580
# Epoch 38/100
# 1169/1174 [============================>.] - ETA: 0s - loss: 0.1449 - accuracy: 0.9463
# Epoch 38: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1450 - accuracy: 0.9463 - val_loss: 0.1152 - val_accuracy: 0.9628
# Epoch 39/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9468
# Epoch 39: saving model to skin.h5
# 1174/1174 [==============================] - 16s 13ms/step - loss: 0.1463 - accuracy: 0.9468 - val_loss: 0.1207 - val_accuracy: 0.9593
# Epoch 40/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9484
# Epoch 40: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1404 - accuracy: 0.9483 - val_loss: 0.1192 - val_accuracy: 0.9626
# Epoch 41/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1396 - accuracy: 0.9485
# Epoch 41: saving model to skin.h5
# 1174/1174 [==============================] - 15s 13ms/step - loss: 0.1396 - accuracy: 0.9485 - val_loss: 0.1455 - val_accuracy: 0.9509
# Epoch 42/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9481
# Epoch 42: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.1411 - accuracy: 0.9481 - val_loss: 0.1079 - val_accuracy: 0.9627
# Epoch 43/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9509
# Epoch 43: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1327 - accuracy: 0.9509 - val_loss: 0.1145 - val_accuracy: 0.9631
# Epoch 44/100
# 1169/1174 [============================>.] - ETA: 0s - loss: 0.1336 - accuracy: 0.9519
# Epoch 44: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1335 - accuracy: 0.9519 - val_loss: 0.1068 - val_accuracy: 0.9643
# Epoch 45/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9529
# Epoch 45: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1274 - accuracy: 0.9528 - val_loss: 0.1042 - val_accuracy: 0.9676
# Epoch 46/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.1236 - accuracy: 0.9546
# Epoch 46: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.1235 - accuracy: 0.9547 - val_loss: 0.1006 - val_accuracy: 0.9681
# Epoch 47/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.1235 - accuracy: 0.9544
# Epoch 47: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.1235 - accuracy: 0.9545 - val_loss: 0.1016 - val_accuracy: 0.9670
# Epoch 48/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.1198 - accuracy: 0.9573
# Epoch 48: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.1198 - accuracy: 0.9573 - val_loss: 0.0995 - val_accuracy: 0.9691
# Epoch 49/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9579
# Epoch 49: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.1164 - accuracy: 0.9579 - val_loss: 0.1029 - val_accuracy: 0.9685
# Epoch 50/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9580
# Epoch 50: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1165 - accuracy: 0.9579 - val_loss: 0.0940 - val_accuracy: 0.9691
# Epoch 51/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9577
# Epoch 51: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.1150 - accuracy: 0.9577 - val_loss: 0.1011 - val_accuracy: 0.9679
# Epoch 52/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1137 - accuracy: 0.9583
# Epoch 52: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.1137 - accuracy: 0.9583 - val_loss: 0.0953 - val_accuracy: 0.9723
# Epoch 53/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1123 - accuracy: 0.9591
# Epoch 53: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.1124 - accuracy: 0.9590 - val_loss: 0.1197 - val_accuracy: 0.9631
# Epoch 54/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1084 - accuracy: 0.9614
# Epoch 54: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1083 - accuracy: 0.9614 - val_loss: 0.0943 - val_accuracy: 0.9720
# Epoch 55/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9603
# Epoch 55: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.1078 - accuracy: 0.9603 - val_loss: 0.1046 - val_accuracy: 0.9688
# Epoch 56/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.1085 - accuracy: 0.9610
# Epoch 56: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.1085 - accuracy: 0.9610 - val_loss: 0.0945 - val_accuracy: 0.9725
# Epoch 57/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9613
# Epoch 57: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.1079 - accuracy: 0.9612 - val_loss: 0.0943 - val_accuracy: 0.9696
# Epoch 58/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.1030 - accuracy: 0.9633
# Epoch 58: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.1030 - accuracy: 0.9632 - val_loss: 0.0827 - val_accuracy: 0.9756
# Epoch 59/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 0.9623
# Epoch 59: saving model to skin.h5
# 1174/1174 [==============================] - 20s 17ms/step - loss: 0.1051 - accuracy: 0.9623 - val_loss: 0.0999 - val_accuracy: 0.9710
# Epoch 60/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9622
# Epoch 60: saving model to skin.h5
# 1174/1174 [==============================] - 19s 16ms/step - loss: 0.1021 - accuracy: 0.9622 - val_loss: 0.1027 - val_accuracy: 0.9693
# Epoch 61/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1005 - accuracy: 0.9627
# Epoch 61: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.1004 - accuracy: 0.9628 - val_loss: 0.0955 - val_accuracy: 0.9736
# Epoch 62/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0941 - accuracy: 0.9657
# Epoch 62: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.0941 - accuracy: 0.9657 - val_loss: 0.0945 - val_accuracy: 0.9729
# Epoch 63/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9645
# Epoch 63: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.1001 - accuracy: 0.9646 - val_loss: 0.0820 - val_accuracy: 0.9755
# Epoch 64/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.0931 - accuracy: 0.9662
# Epoch 64: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.0930 - accuracy: 0.9662 - val_loss: 0.0911 - val_accuracy: 0.9724
# Epoch 65/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.0992 - accuracy: 0.9639
# Epoch 65: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.0993 - accuracy: 0.9639 - val_loss: 0.0891 - val_accuracy: 0.9718
# Epoch 66/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9667
# Epoch 66: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.0928 - accuracy: 0.9667 - val_loss: 0.0867 - val_accuracy: 0.9764
# Epoch 67/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0984 - accuracy: 0.9648
# Epoch 67: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.0984 - accuracy: 0.9648 - val_loss: 0.0839 - val_accuracy: 0.9757
# Epoch 68/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.0934 - accuracy: 0.9660
# Epoch 68: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.0935 - accuracy: 0.9659 - val_loss: 0.0857 - val_accuracy: 0.9743
# Epoch 69/100
# 1170/1174 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.9674
# Epoch 69: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0913 - accuracy: 0.9675 - val_loss: 0.0875 - val_accuracy: 0.9758
# Epoch 70/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.0894 - accuracy: 0.9681
# Epoch 70: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0894 - accuracy: 0.9681 - val_loss: 0.0915 - val_accuracy: 0.9753
# Epoch 71/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0856 - accuracy: 0.9697
# Epoch 71: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0855 - accuracy: 0.9697 - val_loss: 0.0803 - val_accuracy: 0.9788
# Epoch 72/100
# 1169/1174 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9685
# Epoch 72: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.0873 - accuracy: 0.9683 - val_loss: 0.0992 - val_accuracy: 0.9735
# Epoch 73/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0861 - accuracy: 0.9696
# Epoch 73: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0861 - accuracy: 0.9696 - val_loss: 0.1128 - val_accuracy: 0.9691
# Epoch 74/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9692
# Epoch 74: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0851 - accuracy: 0.9692 - val_loss: 0.0854 - val_accuracy: 0.9762
# Epoch 75/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9692
# Epoch 75: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.0846 - accuracy: 0.9692 - val_loss: 0.0879 - val_accuracy: 0.9744
# Epoch 76/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9709
# Epoch 76: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0809 - accuracy: 0.9709 - val_loss: 0.0826 - val_accuracy: 0.9762
# Epoch 77/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9710
# Epoch 77: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.0820 - accuracy: 0.9710 - val_loss: 0.0890 - val_accuracy: 0.9752
# Epoch 78/100
# 1174/1174 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9725
# Epoch 78: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.0769 - accuracy: 0.9725 - val_loss: 0.0765 - val_accuracy: 0.9787
# Epoch 79/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9701
# Epoch 79: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.0831 - accuracy: 0.9701 - val_loss: 0.0937 - val_accuracy: 0.9743
# Epoch 80/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.0814 - accuracy: 0.9700
# Epoch 80: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0814 - accuracy: 0.9700 - val_loss: 0.0913 - val_accuracy: 0.9749
# Epoch 81/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0761 - accuracy: 0.9732
# Epoch 81: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0761 - accuracy: 0.9732 - val_loss: 0.0845 - val_accuracy: 0.9753
# Epoch 82/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.0799 - accuracy: 0.9714
# Epoch 82: saving model to skin.h5
# 1174/1174 [==============================] - 17s 14ms/step - loss: 0.0798 - accuracy: 0.9715 - val_loss: 0.0946 - val_accuracy: 0.9740
# Epoch 83/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.0801 - accuracy: 0.9715
# Epoch 83: saving model to skin.h5
# 1174/1174 [==============================] - 17s 15ms/step - loss: 0.0801 - accuracy: 0.9715 - val_loss: 0.0791 - val_accuracy: 0.9787
# Epoch 84/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0733 - accuracy: 0.9745
# Epoch 84: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.0733 - accuracy: 0.9745 - val_loss: 0.0897 - val_accuracy: 0.9757
# Epoch 85/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.0832 - accuracy: 0.9709
# Epoch 85: saving model to skin.h5
# 1174/1174 [==============================] - 19s 16ms/step - loss: 0.0833 - accuracy: 0.9708 - val_loss: 0.0936 - val_accuracy: 0.9742
# Epoch 86/100
# 1171/1174 [============================>.] - ETA: 0s - loss: 0.0771 - accuracy: 0.9730
# Epoch 86: saving model to skin.h5
# 1174/1174 [==============================] - 18s 15ms/step - loss: 0.0770 - accuracy: 0.9730 - val_loss: 0.1118 - val_accuracy: 0.9723
# Epoch 87/100
# 1173/1174 [============================>.] - ETA: 0s - loss: 0.0753 - accuracy: 0.9738
# Epoch 87: saving model to skin.h5
# 1174/1174 [==============================] - 16s 14ms/step - loss: 0.0752 - accuracy: 0.9738 - val_loss: 0.1017 - val_accuracy: 0.9743
# Epoch 88/100
# 1172/1174 [============================>.] - ETA: 0s - loss: 0.0721 - accuracy: 0.9737
# Epoch 88: saving model to skin.h5
# 1174/1174 [==============================] - 16s 13ms/step - loss: 0.0723 - accuracy: 0.9737 - val_loss: 0.0920 - val_accuracy: 0.9770

# %%
import matplotlib.pyplot as plt
model.evaluate(Xtrain, Ytrain)
model.evaluate(Xtest, Ytest)
# Out:
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - accuracy: 0.1631 - loss: 1.9441
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1603 - loss: 1.9446
# [1.9442353248596191, 0.1666133999824524]

# %%
history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.title('Training and Validation Loss over Epochs') 
plt.grid(True) 
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 history_dict = history.history
#       3 loss_values = history_dict['loss']
#       4 val_loss_values = history_dict['val_loss']
#
# NameError: name 'history' is not defined

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.title('Training and Validation Accuracy over Epochs')
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 history_dict = history.history
#       3 acc_values = history_dict['accuracy']
#       4 val_acc_values = history_dict['val_accuracy']
#
# NameError: name 'history' is not defined

# %%
# Generate predicted probabilities for the test set
from sklearn.metrics import classification_report


y_pred_prob_test = model.predict(Xtest)
# Convert probabilities to class labels
y_pred_test = np.argmax(y_pred_prob_test, axis=1)

# Print classification report
print("Classification Report:")
print(classification_report(Ytest, y_pred_test))
# Out:
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1328
#            1       0.20      0.23      0.21      1376
#            2       0.00      0.00      0.00      1366
#            3       0.16      0.78      0.27      1368
#            4       0.00      0.00      0.00      1299
#            5       0.16      0.14      0.15      1300
#            6       0.00      0.00      0.00      1350
#
#     accuracy                           0.17      9387
#    macro avg       0.07      0.16      0.09      9387
# weighted avg       0.07      0.17      0.09      9387
# C:\Users\Sneha\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Sneha\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Sneha\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate predicted probabilities for the test set
y_pred_prob_test = model.predict(Xtest)
# Convert probabilities to class labels
y_pred_test = np.argmax(y_pred_prob_test, axis=1)

# Generate confusion matrix
cm = confusion_matrix(Ytest, y_pred_test)

# Plot confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step

# %%
# Get the counts of different skin cancer types
skin_cancer_counts = meta_df['dx'].value_counts()

# Plot the bar graph
plt.figure(figsize=(6, 4))
skin_cancer_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Different Types of Skin Cancer')
plt.xlabel('Skin Cancer Types')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
